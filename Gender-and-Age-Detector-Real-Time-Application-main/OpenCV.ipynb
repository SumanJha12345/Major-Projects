# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hp\appdata\roaming\python\python39\site-packages (from opencv-python) (1.24.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
img1=cv2.imread("Data/1.jpg",0)
plt.imshow(img1)

# %%
img2=cv2.imread("Data/2.jpg",0)

# %%
result=img1+img2

# %%
plt.imshow(result)

# %%
result=img1-img2

# %%
plt.imshow(result)

# %%
result=img1*img2
plt.imshow(result)

# %%
result=img1/img2
plt.imshow(result)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5000\1580248168.py:1: RuntimeWarning: divide by zero encountered in divide
#   result=img1/img2

# %%
img1=cv2.imread("Data/1.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")     
plt.xticks([]),plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img1=cv2.imread("Data/1.jpg")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
reszoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
